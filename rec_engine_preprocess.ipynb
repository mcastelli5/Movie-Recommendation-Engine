# %%
# Setup environment
from IPython.display import display
import pandas as pd
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import spacy
from gensim.models.word2vec import Word2Vec
from collections import Counter
from string import punctuation
from ast import literal_eval

# %%
movies = pd.read_csv('data/cleaned_movies.csv', converters={"Genre": literal_eval})
display(movies)
# Out:
#                  Series_Title  Released_Year Certificate  \
# 0    The Shawshank Redemption           1994       Adult
# 1               The Godfather           1972       Adult
# 2             The Dark Knight           2008       Adult
# 3      The Godfather: Part II           1974       Adult
# 4                12 Angry Men           1957      Family
# ..                        ...            ...         ...
# 995    Breakfast at Tiffany's           1961       Adult
# 996                     Giant           1956         NaN
# 997     From Here to Eternity           1953       Adult
# 998                  Lifeboat           1944       Adult
# 999              The 39 Steps           1935       Adult
#
#                             Genre  IMDB_Rating  \
# 0                         [Drama]          9.3
# 1                 [Crime,  Drama]          9.2
# 2        [Action,  Crime,  Drama]          9.0
# 3                 [Crime,  Drama]          9.0
# 4                 [Crime,  Drama]          9.0
# ..                            ...          ...
# 995    [Comedy,  Drama,  Romance]          7.6
# 996             [Drama,  Western]          7.6
# 997       [Drama,  Romance,  War]          7.6
# 998                 [Drama,  War]          7.6
# 999  [Crime,  Mystery,  Thriller]          7.6
#
#                                               Overview              Director  \
# 0    Two imprisoned men bond over a number of years...        Frank Darabont
# 1    An organized crime dynasty's aging patriarch t...  Francis Ford Coppola
# 2    When the menace known as the Joker wreaks havo...     Christopher Nolan
# 3    The early life and career of Vito Corleone in ...  Francis Ford Coppola
# 4    A jury holdout attempts to prevent a miscarria...          Sidney Lumet
# ..                                                 ...                   ...
# 995  A young New York socialite becomes interested ...         Blake Edwards
# 996  Sprawling epic covering the life of a Texas ca...        George Stevens
# 997  In Hawaii in 1941, a private is cruelly punish...        Fred Zinnemann
# 998  Several survivors of a torpedoed merchant ship...      Alfred Hitchcock
# 999  A man in London tries to help a counter-espion...      Alfred Hitchcock
#
#                  Star1              Star2           Star3           Star4
# 0          Tim Robbins     Morgan Freeman      Bob Gunton  William Sadler
# 1        Marlon Brando          Al Pacino      James Caan    Diane Keaton
# 2       Christian Bale       Heath Ledger   Aaron Eckhart   Michael Caine
# 3            Al Pacino     Robert De Niro   Robert Duvall    Diane Keaton
# 4          Henry Fonda        Lee J. Cobb   Martin Balsam    John Fiedler
# ..                 ...                ...             ...             ...
# 995     Audrey Hepburn     George Peppard   Patricia Neal     Buddy Ebsen
# 996   Elizabeth Taylor        Rock Hudson      James Dean   Carroll Baker
# 997     Burt Lancaster   Montgomery Clift    Deborah Kerr      Donna Reed
# 998  Tallulah Bankhead        John Hodiak   Walter Slezak  William Bendix
# 999       Robert Donat  Madeleine Carroll  Lucie Mannheim  Godfrey Tearle
#
# [1000 rows x 11 columns]

# %% [markdown]
# Recommendation Engine Preprocessing

# %%
# Load spacy model for keyword recognition
nlp = spacy.load("en_core_web_sm")

# %%
# Create function that grabs all keywords that are proper nouns, adjectives, or nouns
def get_keywords(text):
    result = []
    pos_tag = ['PROPN', 'ADJ', 'NOUN']
    doc = nlp(text.lower())
    for token in doc:
        if token.text in nlp.Defaults.stop_words or token.text in punctuation:
            continue
        if token.pos_ in pos_tag:
            result.append(token.text)
    
    # return list of unique keywords
    return set(result)

# %%
# Create Keywords column in movies df
movies['Keywords'] = movies.Overview.apply(lambda x: get_keywords(x))

# %%
display(movies)
# Out:
#                  Series_Title  Released_Year Certificate  \
# 0    The Shawshank Redemption           1994       Adult
# 1               The Godfather           1972       Adult
# 2             The Dark Knight           2008       Adult
# 3      The Godfather: Part II           1974       Adult
# 4                12 Angry Men           1957      Family
# ..                        ...            ...         ...
# 995    Breakfast at Tiffany's           1961       Adult
# 996                     Giant           1956         NaN
# 997     From Here to Eternity           1953       Adult
# 998                  Lifeboat           1944       Adult
# 999              The 39 Steps           1935       Adult
#
#                             Genre  IMDB_Rating  \
# 0                         [Drama]          9.3
# 1                 [Crime,  Drama]          9.2
# 2        [Action,  Crime,  Drama]          9.0
# 3                 [Crime,  Drama]          9.0
# 4                 [Crime,  Drama]          9.0
# ..                            ...          ...
# 995    [Comedy,  Drama,  Romance]          7.6
# 996             [Drama,  Western]          7.6
# 997       [Drama,  Romance,  War]          7.6
# 998                 [Drama,  War]          7.6
# 999  [Crime,  Mystery,  Thriller]          7.6
#
#                                               Overview              Director  \
# 0    Two imprisoned men bond over a number of years...        Frank Darabont
# 1    An organized crime dynasty's aging patriarch t...  Francis Ford Coppola
# 2    When the menace known as the Joker wreaks havo...     Christopher Nolan
# 3    The early life and career of Vito Corleone in ...  Francis Ford Coppola
# 4    A jury holdout attempts to prevent a miscarria...          Sidney Lumet
# ..                                                 ...                   ...
# 995  A young New York socialite becomes interested ...         Blake Edwards
# 996  Sprawling epic covering the life of a Texas ca...        George Stevens
# 997  In Hawaii in 1941, a private is cruelly punish...        Fred Zinnemann
# 998  Several survivors of a torpedoed merchant ship...      Alfred Hitchcock
# 999  A man in London tries to help a counter-espion...      Alfred Hitchcock
#
#                  Star1              Star2           Star3           Star4  \
# 0          Tim Robbins     Morgan Freeman      Bob Gunton  William Sadler
# 1        Marlon Brando          Al Pacino      James Caan    Diane Keaton
# 2       Christian Bale       Heath Ledger   Aaron Eckhart   Michael Caine
# 3            Al Pacino     Robert De Niro   Robert Duvall    Diane Keaton
# 4          Henry Fonda        Lee J. Cobb   Martin Balsam    John Fiedler
# ..                 ...                ...             ...             ...
# 995     Audrey Hepburn     George Peppard   Patricia Neal     Buddy Ebsen
# 996   Elizabeth Taylor        Rock Hudson      James Dean   Carroll Baker
# 997     Burt Lancaster   Montgomery Clift    Deborah Kerr      Donna Reed
# 998  Tallulah Bankhead        John Hodiak   Walter Slezak  William Bendix
# 999       Robert Donat  Madeleine Carroll  Lucie Mannheim  Godfrey Tearle
#
#                                               Keywords
# 0    {decency, men, number, acts, common, solace, y...
# 1    {transfers, control, son, reluctant, dynasty, ...
# 2    {psychological, menace, gotham, tests, batman,...
# 3    {corleone, career, vito, york, city, new, mich...
# 4    {attempts, evidence, holdout, colleagues, jury...
# ..                                                 ...
# 995  {young, interested, man, socialite, way, york,...
# 996    {texas, cattle, epic, family, associates, life}
# 997  {command, love, team, wife, private, captain, ...
# 998  {ii, crew, war, world, lifeboat, members, u, t...
# 999  {man, london, ring, agent, information, espion...
#
# [1000 rows x 12 columns]

# %%
# Create function to clean feature columns for rec model
def clean_data(x):
    if isinstance(x, list):
        return " ".join([str.lower(word) for word in x])
    else:
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return " "

# %%
# Apply clean data function to transform the feature columns
features = ['Genre', 'Director', 'Star1', 'Star2', 'Star3', 'Star4', 'Keywords']
for feature in features:
    movies[feature] = movies[feature].apply(clean_data)

# %%
display(movies)
# Out:
#                  Series_Title  Released_Year Certificate  \
# 0    The Shawshank Redemption           1994       Adult
# 1               The Godfather           1972       Adult
# 2             The Dark Knight           2008       Adult
# 3      The Godfather: Part II           1974       Adult
# 4                12 Angry Men           1957      Family
# ..                        ...            ...         ...
# 995    Breakfast at Tiffany's           1961       Adult
# 996                     Giant           1956         NaN
# 997     From Here to Eternity           1953       Adult
# 998                  Lifeboat           1944       Adult
# 999              The 39 Steps           1935       Adult
#
#                         Genre  IMDB_Rating  \
# 0                       drama          9.3
# 1                crime  drama          9.2
# 2        action  crime  drama          9.0
# 3                crime  drama          9.0
# 4                crime  drama          9.0
# ..                        ...          ...
# 995    comedy  drama  romance          7.6
# 996            drama  western          7.6
# 997       drama  romance  war          7.6
# 998                drama  war          7.6
# 999  crime  mystery  thriller          7.6
#
#                                               Overview            Director  \
# 0    Two imprisoned men bond over a number of years...       frankdarabont
# 1    An organized crime dynasty's aging patriarch t...  francisfordcoppola
# 2    When the menace known as the Joker wreaks havo...    christophernolan
# 3    The early life and career of Vito Corleone in ...  francisfordcoppola
# 4    A jury holdout attempts to prevent a miscarria...         sidneylumet
# ..                                                 ...                 ...
# 995  A young New York socialite becomes interested ...        blakeedwards
# 996  Sprawling epic covering the life of a Texas ca...       georgestevens
# 997  In Hawaii in 1941, a private is cruelly punish...       fredzinnemann
# 998  Several survivors of a torpedoed merchant ship...     alfredhitchcock
# 999  A man in London tries to help a counter-espion...     alfredhitchcock
#
#                 Star1             Star2          Star3          Star4 Keywords
# 0          timrobbins     morganfreeman      bobgunton  williamsadler
# 1        marlonbrando          alpacino      jamescaan    dianekeaton
# 2       christianbale       heathledger   aaroneckhart   michaelcaine
# 3            alpacino      robertdeniro   robertduvall    dianekeaton
# 4          henryfonda         leej.cobb   martinbalsam    johnfiedler
# ..                ...               ...            ...            ...      ...
# 995     audreyhepburn     georgepeppard   patricianeal     buddyebsen
# 996   elizabethtaylor        rockhudson      jamesdean   carrollbaker
# 997     burtlancaster   montgomeryclift    deborahkerr      donnareed
# 998  tallulahbankhead        johnhodiak   walterslezak  williambendix
# 999       robertdonat  madeleinecarroll  luciemannheim  godfreytearle
#
# [1000 rows x 12 columns]

# %%
features = ['Genre', 'Director', 'Star1', 'Star2', 'Star3', 'Star4', 'Keywords']

# %%
# Create function for word soup column
def create_soup(x):
    return x.Genre + ' ' + x.Director + ' ' + x.Star1 + ' ' + x.Star2 + ' ' + x.Star3 + ' ' + x.Star4 + ' ' + x.Keywords

# %%
# Create soup column in movies df
movies['soup'] = movies.apply(create_soup, axis=1)

# %%
display(movies.soup[0])
# Out:
# 'drama frankdarabont timrobbins morganfreeman bobgunton williamsadler  '

# %%
# Save df to data directory
movies.to_csv(path_or_buf='data/preprocessed_movies.csv', index=False)
