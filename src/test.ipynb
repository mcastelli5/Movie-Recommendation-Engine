# %%
# Test different recommendation scenarios (with same values building on top of each other to see how the recommendations change)

# %%
from top_movies_rec import top_movies_rec
from content_based_rec import content_based_rec
from collab_filtering_rec import collab_based_rec
from hybrid_rec import hybrid_rec

def get_rec(search_terms: list = [], fave_movie: str = None):
    """
    Summary:
        decide what strategy is used to return recommnedations to the user based on the preferences that they provided.

    Args:
        search_terms (list, optional): keywords input by the user that can be used to match similar words in movies. Defaults to [].
        fave_movie (str, optional): user's favorite movie that can be used to find similar users that have rated other movies. Defaults to None.
    """
    
    # Top Movies Recommendation
    if not search_terms and not fave_movie:
        rec_df = top_movies_rec()
        print("top_movies_rec")

    # Content-based Recommendation
    elif search_terms and not fave_movie:
        rec_df = content_based_rec(search_terms=search_terms)
        print("content_based_rec")

    # Collaborative Filtering Recommendation
    elif not search_terms and fave_movie:
        rec_df = collab_based_rec(fave_movie=fave_movie)
        print("collab_based_rec")
        
    # Hybrid Recommendation
    elif search_terms and fave_movie:
        rec_df = hybrid_rec(search_terms, fave_movie)
        print("hybrid_rec")
        
    # Get top 20 recommendations (in order)
    ranked_titles = []
    for idx, row in rec_df.iterrows():
        ranked_titles.append([idx, row.title])
    
    # Return the recommendations to be shown to the user
    return rec_df

# %%
display(get_rec())
# Out:
# top_movies_rec
#                                                genres      id  \
# 0      ['family', 'animation', 'adventure', 'comedy']  211672
# 1   ['adventure', 'family', 'animation', 'action',...  177572
# 2                   ['action', 'adventure', 'comedy']  293660
# 3   ['action', 'adventure', 'fantasy', 'sciencefic...   19995
# 4                              ['action', 'thriller']  245891
# 5                    ['mystery', 'thriller', 'drama']  210577
# 6         ['sciencefiction', 'adventure', 'thriller']  131631
# 7           ['adventure', 'action', 'sciencefiction']  271110
# 8                               ['thriller', 'crime']     680
# 9            ['drama', 'action', 'crime', 'thriller']     155
# 10            ['sciencefiction', 'drama', 'thriller']      78
# 11          ['sciencefiction', 'action', 'adventure']   24428
# 12  ['action', 'mystery', 'sciencefiction', 'thril...  198663
# 13  ['sciencefiction', 'action', 'drama', 'thriller']  119450
# 14                                          ['drama']  244786
# 15                                          ['drama']     550
# 16          ['action', 'sciencefiction', 'adventure']  118340
# 17                                 ['drama', 'crime']     278
# 18                     ['comedy', 'drama', 'romance']      13
# 19                 ['adventure', 'fantasy', 'action']      22
#
#                                              overview  popularity  \
# 0   Minions Stuart, Kevin and Bob are recruited by...  547.488298
# 1   The special bond that develops between plus-si...  213.849907
# 2   Deadpool tells the origin story of former Spec...  187.860492
# 3   In the 22nd century, a paraplegic Marine is di...  185.070892
# 4   Ex-lunatic John Wick comes off his meds to tra...  183.870374
# 5   With his wife's disappearance having become th...  154.801009
# 6   Katniss Everdeen reluctantly becomes the symbo...  147.098006
# 7   Following the events of Age of Ultron, the col...  145.882135
# 8   A burger-loving hit man, his philosophical par...  140.950236
# 9   Batman raises the stakes in his war on crime. ...  123.167259
# 10  In the smog-choked dystopian Los Angeles of 20...   96.272374
# 11  When an unexpected enemy emerges and threatens...   89.887648
# 12  Set in a post-apocalyptic world, young Thomas ...   76.937890
# 13  A group of scientists in San Francisco struggl...   75.385211
# 14  Under the direction of a ruthless instructor, ...   64.299990
# 15  A ticking-time-bomb insomniac and a slippery s...   63.869599
# 16  Light years from Earth, 26 years after being a...   53.291601
# 17  Framed in the 1940s for the double murder of h...   51.645403
# 18  A man with a low IQ has accomplished great thi...   48.307194
# 19  Jack Sparrow, a freewheeling 17th-century pira...   47.326665
#
#                          poster_path release_date  runtime  \
# 0    /q0R4crx2SehcEEQEkYObktdeFy.jpg   2015-06-17     91.0
# 1   /9gLu47Zw5ertuFTZaxXOvNfy78T.jpg   2014-10-24    102.0
# 2   /inVq3FRqcYIRl2la8iZikYYxFNR.jpg   2016-02-09    108.0
# 3   /kmcqlZGaSh20zpTbuoF0Cdn07dT.jpg   2009-12-10    162.0
# 4    /5vHssUeVe25bMrof1HyaPyWgaP.jpg   2014-10-22    101.0
# 5   /gdiLTof3rbPDAmPaCf4g6op46bj.jpg   2014-10-01    145.0
# 6   /gj282Pniaa78ZJfbaixyLXnXEDI.jpg   2014-11-18    123.0
# 7   /kSBXou5Ac7vEqKd97wotJumyJvU.jpg   2016-04-27    147.0
# 8    /dM2w364MScsjFf8pfMbaWUcWrR.jpg   1994-09-10    154.0
# 9   /1hRoyzDtpgMU7Dz4JF22RANzQO7.jpg   2008-07-16    152.0
# 10  /p64TtbZGCElxQHpAMWmDHkWJlH2.jpg   1982-06-25    117.0
# 11  /cezWGskPY5x7GaglTTRN4Fugfb8.jpg   2012-04-25    143.0
# 12  /coss7RgL0NH6g4fC2s5atvf3dFO.jpg   2014-09-10    113.0
# 13  /2EUAUIu5lHFlkj5FRryohlH6CRO.jpg   2014-06-26    130.0
# 14  /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg   2014-10-10    105.0
# 15  /adw6Lq9FiC9zjYEpOqfq03ituwp.jpg   1999-10-15    139.0
# 16  /y31QB9kn3XSudA15tV7UWQ9XLuW.jpg   2014-07-30    121.0
# 17  /9O7gLzmreU0nGkIB6K3BsJbzvNv.jpg   1994-09-23    142.0
# 18  /yE5d3BUhE8hCnkMUJOo1QDoOGNz.jpg   1994-07-06    142.0
# 19  /tkt9xR1kNX5R9rCebASKck44si2.jpg   2003-07-09    143.0
#
#                                                 title  vote_average  \
# 0                                             Minions           6.4
# 1                                          Big Hero 6           7.8
# 2                                            Deadpool           7.4
# 3                                              Avatar           7.2
# 4                                           John Wick           7.0
# 5                                           Gone Girl           7.9
# 6               The Hunger Games: Mockingjay - Part 1           6.6
# 7                          Captain America: Civil War           7.1
# 8                                        Pulp Fiction           8.3
# 9                                     The Dark Knight           8.3
# 10                                       Blade Runner           7.9
# 11                                       The Avengers           7.4
# 12                                    The Maze Runner           7.0
# 13                     Dawn of the Planet of the Apes           7.3
# 14                                           Whiplash           8.3
# 15                                         Fight Club           8.3
# 16                            Guardians of the Galaxy           7.9
# 17                           The Shawshank Redemption           8.5
# 18                                       Forrest Gump           8.2
# 19  Pirates of the Caribbean: The Curse of the Bla...           7.5
#
#                                              keywords  \
# 0   ['assistant', 'aftercreditsstinger', 'duringcr...
# 1   ['brotherbrotherrelationship', 'hero', 'talent...
# 2   ['antihero', 'mercenary', 'marvelcomic', 'supe...
# 3   ['cultureclash', 'future', 'spacewar', 'spacec...
# 4   ['hitman', 'russianmafia', 'revenge', 'murder'...
# 5   ['basedonnovel', 'marriagecrisis', 'disappeara...
# 6   ['resistance', 'post-apocalyptic', 'dystopia',...
# 7   ['civilwar', 'war', 'marvelcomic', 'sequel', '...
# 8   ['transporter', 'brothel', 'drugdealer', 'boxe...
# 9   ['dccomics', 'crimefighter', 'secretidentity',...
# 10  ['artificialintelligence', 'bountyhunter', 'dy...
# 11  ['newyork', 'shield', 'marvelcomic', 'superher...
# 12  ['basedonnovel', 'maze', 'post-apocalyptic', '...
# 13  ['leader', 'colony', 'post-apocalyptic', 'dyst...
# 14  ['jazz', 'obsession', 'conservatory', 'musicte...
# 15  ['supportgroup', 'dualidentity', 'nihilism', '...
# 16  ['marvelcomic', 'spaceship', 'space', 'outersp...
# 17  ['prison', 'corruption', 'policebrutality', 'p...
# 18  ['vietnamveteran', 'hippie', 'mentallydisabled...
# 19  ['exoticisland', 'blacksmith', 'eastindiatradi...
#
#                                                  soup  rating_id
# 0   assistant aftercreditsstinger duringcreditssti...     135887
# 1   brotherbrotherrelationship hero talent revenge...     115617
# 2   antihero mercenary marvelcomic superhero based...     122904
# 3   cultureclash future spacewar spacecolony socie...      72998
# 4   hitman russianmafia revenge murder gangster do...     115149
# 5   basedonnovel marriagecrisis disappearance chea...     112556
# 6   resistance post-apocalyptic dystopia war seque...     116823
# 7   civilwar war marvelcomic sequel superhero base...     122920
# 8   transporter brothel drugdealer boxer massage s...        296
# 9   dccomics crimefighter secretidentity scarecrow...      58559
# 10  artificialintelligence bountyhunter dystopia g...        541
# 11  newyork shield marvelcomic superhero basedonco...      89745
# 12  basedonnovel maze post-apocalyptic dystopia es...     114180
# 13  leader colony post-apocalyptic dystopia forest...     112623
# 14  jazz obsession conservatory musicteacher newyo...     112552
# 15  supportgroup dualidentity nihilism rageandhate...       2959
# 16  marvelcomic spaceship space outerspace orphan ...     112852
# 17  prison corruption policebrutality prisoncell d...        318
# 18  vietnamveteran hippie mentallydisabled running...        356
# 19  exoticisland blacksmith eastindiatradingcompan...       6539

# %%
display(get_rec(search_terms=['comedy', 'thriller', 'hilarious', 'fun']))
# Out:
# /Users/matthewcastelli/Desktop/Movie-Recommendations-ChatBot/src/content_based_rec.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row)
# content_based_rec
#                                                genres      id  \
# 0                              ['comedy', 'thriller']  101519
# 1                    ['action', 'comedy', 'thriller']    2185
# 2                     ['comedy', 'thriller', 'crime']    2122
# 3       ['adventure', 'action', 'comedy', 'thriller']   16820
# 4                   ['comedy', 'thriller', 'mystery']   47898
# 5         ['action', 'comedy', 'thriller', 'romance']   37821
# 6       ['adventure', 'action', 'comedy', 'thriller']   35463
# 7          ['comedy', 'thriller', 'crime', 'mystery']   14584
# 8        ['comedy', 'thriller', 'mystery', 'romance']   18649
# 9          ['action', 'comedy', 'thriller', 'family']   11890
# 10      ['action', 'adventure', 'comedy', 'thriller']   11375
# 11      ['action', 'adventure', 'comedy', 'thriller']   10762
# 12      ['action', 'adventure', 'comedy', 'thriller']   13191
# 13                    ['thriller', 'comedy', 'crime']  162145
# 14         ['comedy', 'thriller', 'crime', 'romance']   28121
# 15        ['action', 'comedy', 'thriller', 'romance']    9434
# 16                   ['comedy', 'thriller', 'horror']   10552
# 17  ['action', 'comedy', 'thriller', 'crime', 'fam...    6951
# 18          ['action', 'comedy', 'thriller', 'crime']   16806
# 19                   ['action', 'comedy', 'thriller']   11382
#
#                                              overview  popularity  \
# 0   Jack is a children's author turned crime novel...    5.507377
# 1   The story of how a mysterious suitcase brings ...    5.761051
# 2   Jimmy 'The Tulip' Tudeski now spends his days ...    7.156060
# 3   F/X man Rollie Tyler is now a toymaker. Mike, ...    3.186817
# 4   Betty Lou is a librarian in a very small town....    1.386549
# 5   When an elite assassin marries a beautiful com...    6.540621
# 6   Rita Rizzoli is a narcotics cop with a plethor...    1.473833
# 7   Spoofing the entire 1940s detective genre, and...    3.351441
# 8   Baby photographer Ronnie Jackson, on death row...    1.196569
# 9   Angelo "Snaps" Provolone made his dying father...    6.137796
# 10  Joe Gavilan (Harrison Ford) and his new partne...   11.080439
# 11  Three friends, whose lives have been drifting ...    6.046516
# 12  War Inc. is set in the future, when the fictio...    4.800426
# 13  When 19-year-old Adam agrees to do a day's dri...    6.301471
# 14  Nightclub manager Darnell Wright is a perpetua...    2.256747
# 15  Martin Blank is a freelance hitman who starts ...    7.556814
# 16  Three short stories by shock-meister Stephen K...    6.781815
# 17  Scott Turner has 3 days left in the local poli...   12.372038
# 18  Set in the 1930s, an honest, goodhearted man i...    4.063135
# 19  Set in 1920's New York City, this movie tells ...    5.722880
#
#                          poster_path release_date  runtime  \
# 0   /6UY0O2FHOdrI87yR16mce5WsJP1.jpg   2012-06-07    100.0
# 1   /h844gBztdYMLrroUen6qbsomrGx.jpg   2002-04-05     85.0
# 2   /pc2xIaRjmOxBiVqluPISzHRTKSr.jpg   2004-04-07     98.0
# 3   /v44Ozx00NDrYYvvqI9fMVPHU0Gz.jpg   1991-04-16    108.0
# 4   /6i49dt0mQM2piyTjLFQzxJkOF51.jpg   1992-08-21     89.0
# 5   /bQHs6vyYwvxYvWEIi1G9rk4qNdw.jpg   2010-06-04    100.0
# 6   /bobwwl5NB10N5qfPOwOHb3DyJcT.jpg   1987-10-30    104.0
# 7   /sdsxpDKBO5ksgZ2pLiBPEgSoZG8.jpg   1978-06-23     92.0
# 8   /5e4bdXZKUl1AH755vICEcSiOocL.jpg   1947-04-04     87.0
# 9   /yAHSrlNZeVN9kwk7eVTWPzbdYEF.jpg   1991-04-26    109.0
# 10  /15xHKnXY6WmWcmwiWhzYY9e60Nc.jpg   2003-06-09    116.0
# 11  /oZDbFtTnTwW5GSfyaGFGaYxDBgD.jpg   2004-08-20     95.0
# 12  /xrpH4CvTKTz3uo6mWlLclVUKVo4.jpg   2008-04-28    106.0
# 13  /wpjO1o7dav8ZTPJg0CiuXL5C7DF.jpg   2012-11-24     95.0
# 14  /sDDdImTQGeMYqSQgKNlZCrzmfgt.jpg   1996-04-04    108.0
# 15  /3qn4gjft8dl5syUDpmPvWqCPFAf.jpg   1997-04-11    107.0
# 16  /A65sQJbEAAV4wC9QQc0Mn4ZaMZV.jpg   1985-04-12     94.0
# 17  /oSvaWdWISYCIySdg2TUOHTTapkS.jpg   1989-07-28    100.0
# 18  /vTm2PygQZLLsK6AsKJJfmVqYho9.jpg   1984-12-21     90.0
# 19  /tfplmiNdTDHHbZZ8AGmXBiB1xJj.jpg   1994-10-14     98.0
#
#                                 title  vote_average  \
# 0      A Fantastic Fear of Everything           5.7
# 1                         Big Trouble           6.3
# 2                 The Whole Ten Yards           5.5
# 3                                F/X2           5.8
# 4      The Gun in Betty Lou's Handbag           4.1
# 5                             Killers           5.7
# 6                        Fatal Beauty           5.3
# 7                 The Cheap Detective           6.6
# 8                My Favorite Brunette           6.6
# 9                               Oscar           6.2
# 10                 Hollywood Homicide           5.0
# 11                   Without a Paddle           5.3
# 12                          War, Inc.           5.6
# 13                      The Liability           5.7
# 14  A Thin Line Between Love and Hate           5.7
# 15                Grosse Pointe Blank           6.9
# 16                          Cat's Eye           5.9
# 17                     Turner & Hooch           5.9
# 18                 Johnny Dangerously           6.3
# 19              Bullets Over Broadway           7.0
#
#                                              keywords  \
# 0                                        ['paranoia']
# 1                                          ['gadfly']
# 2                                          ['hitman']
# 3                                      ['technology']
# 4                             ['murder', 'librarian']
# 5                                        ['assassin']
# 6                                  ['police', 'drug']
# 7                               ['spoof', 'samspade']
# 8                       ['amateurdetective', 'spoof']
# 9                          ['honesty', 'businessman']
# 10                             ['rapmusic', 'hitman']
# 11                 ['deathofafriend', 'treasurehunt']
# 12                      ['hitman', 'politicalsatire']
# 13                          ['thriller', 'roadmovie']
# 14           ['revenge', 'africanamerican', 'dating']
# 15  ['missionofmurder', 'schoolparty', 'highschool...
# 16          ['smoking', 'cat', 'menace', 'anthology']
# 17                       ['eatingnonfood', 'petfood']
# 18     ['organizedcrime', 'mobster', 'womandirector']
# 19  ['lover(female)', 'talent', 'mafiaboss', 'auth...
#
#                                                  soup  rating_id
# 0                            paranoia comedy thriller      98279
# 1                       gadfly action comedy thriller       4774
# 2                        hitman comedy thriller crime       7381
# 3         technology adventure action comedy thriller       3764
# 4            murder librarian comedy thriller mystery       6829
# 5             assassin action comedy thriller romance      78041
# 6        police drug adventure action comedy thriller       3716
# 7        spoof samspade comedy thriller crime mystery       4925
# 8   amateurdetective spoof comedy thriller mystery...       5167
# 9   honesty businessman action comedy thriller family       6424
# 10   rapmusic hitman action adventure comedy thriller       6484
# 11  deathofafriend treasurehunt action adventure c...       8814
# 12  hitman politicalsatire action adventure comedy...      59594
# 13           thriller roadmovie thriller comedy crime     100304
# 14  revenge africanamerican dating comedy thriller...        626
# 15  missionofmurder schoolparty highschoolreunion ...       1500
# 16  smoking cat menace anthology comedy thriller h...       2787
# 17  eatingnonfood petfood action comedy thriller c...       4677
# 18  organizedcrime mobster womandirector action co...       5568
# 19  lover(female) talent mafiaboss author action c...        348

# %%
display(get_rec(search_terms=['comedy', 'thriller', 'hilarious', 'fun'], fave_movie="Toy Story"))
# Out:
# /Users/matthewcastelli/Desktop/Movie-Recommendations-ChatBot/src/content_based_rec.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row)
# hybrid_rec
#     rnk                                        genres      id  \
# 0     3                         ['action', 'fantasy']     364
# 1     0                      ['documentary', 'music']  391698
# 2     2                                  ['thriller']    9491
# 3     4                ['crime', 'drama', 'thriller']  242582
# 4     5                         ['comedy', 'romance']   27995
# 5     6           ['thriller', 'action', 'adventure']   20681
# 6     7                           ['action', 'drama']   78734
# 7     8                          ['drama', 'romance']   22318
# 8     9                  ['comedy', 'sciencefiction']    2277
# 9    10                        ['action', 'thriller']   57351
# 10   11                ['comedy', 'drama', 'romance']   13665
# 11   12                                     ['drama']   10052
# 12   13     ['adventure', 'action', 'sciencefiction']   36657
# 13   14                                    ['comedy']   10758
# 14   15                          ['comedy', 'family']   10406
# 15   16                                     ['drama']   28171
# 16   17    ['comedy', 'family', 'mystery', 'romance']   13343
# 17   18            ['adventure', 'fantasy', 'family']   12444
# 18   19                         ['history', 'comedy']   11686
# 19    1  ['romance', 'fantasy', 'animation', 'music']    3933
#
#                                              overview  popularity  \
# 0   Having defeated the Joker, Batman now faces th...   15.001681
# 1   The band stormed Europe in 1963, and, in 1964,...    7.078301
# 2   A female rookie in the police force engages in...    5.200399
# 3   When Lou Bloom, desperate for work, muscles in...   21.277073
# 4   The story of Nola Darling's simultaneous sexua...    7.056652
# 5   Mercenary James Shannon, on a reconnaissance j...    3.998970
# 6   The O'Leary brothers -- honest Jack and roguis...    2.599163
# 7   Ben Stiller plays comedy writer Jerry Stahl, w...    3.357962
# 8   Richard Martin buys a gift, a new NDR-114 robo...    9.369918
# 9   Malik Bishop is the best killer in the busines...    0.210241
# 10  Arthur is the most quotable drunk millionaire ...   14.911301
# 11  A grieving doctor is being contacted by his la...    4.924078
# 12  Two mutants, Rogue and Wolverine, come to a pr...    0.954467
# 13  Jenna is a pregnant, unhappily married waitres...   11.276024
# 14  High school misfits Stoney and Dave discover a...    8.000189
# 15  After an Afghanistan-born woman who lives in C...    1.462073
# 16  Luther Heggs aspires to being a reporter for h...    1.907872
# 17  Harry, Ron and Hermione walk away from their l...   23.300362
# 18  Set in 19th-century Russia, Allen is a cowardl...    5.165666
# 19  Set in a 19th-century european village, this s...   12.920032
#
#                          poster_path release_date  runtime  \
# 0   /jX5THE1yW3zTdeD9dupcIyQvKiG.jpg   1992-06-19    126.0
# 1   /uv7syi4vRyjvWoB8qExbqnbuCu5.jpg   2016-09-15     99.0
# 2   /sftcJ7tCcL2DYFcJVL4ds4Zg7wt.jpg   1990-03-16    102.0
# 3   /8oPY6ULFOTbAEskySNhgsUIN4fW.jpg   2014-10-23    117.0
# 4    /qiJuXvPONqTSSnzhbCBqE7EotV.jpg   1986-08-08     84.0
# 5   /mC39RlWfat7wVxnGOVv0Lir5gFC.jpg   1980-12-17    118.0
# 6   /lSkLiVmxECi0DbOwG4bogsN9vob.jpg   1937-04-14     95.0
# 7   /vbI0JizS0SmWzRm9wQXqjcL3mVz.jpg   1998-09-12     88.0
# 8   /pt57Kwkd2g2xdYFZKx3yCoz9Xim.jpg   1999-12-17    131.0
# 9   /67fIrwMiSQ26Q2uUo1jz6B6kxID.jpg   2002-08-30     85.0
# 10  /lg5IojZvRMiiDabnxSxh8RC49QO.jpg   1981-07-17     97.0
# 11  /gs3fFBoiEaExy5x3m5yAQpmVhXs.jpg   2002-02-22    104.0
# 12  /k01Q6ATbfzNJgw4Zuoj0LTY3T9x.jpg   2000-07-13    104.0
# 13  /88FWNhsEvnCGELvUgQEpZ1E5nd5.jpg   2007-05-25    108.0
# 14  /xSjdE12wXgdJwX3mvGAniNFMbTi.jpg   1992-05-22     88.0
# 15   /NBtNYNV2Plp3nfcbXTL3XNjeQw.jpg   2001-05-11     85.0
# 16  /50AWIt4hC0VoMHb4bdlE7D4AsyB.jpg   1966-01-20     90.0
# 17  /maP4MTfPCeVD2FZbKTLUgriOW4R.jpg   2010-10-17    146.0
# 18  /qRNisGLmcHoEvMjzcvVlcdCnOhO.jpg   1975-06-10     85.0
# 19  /o9GbcdP7rOg2m1NyUnUR3ZwNcTE.jpg   2005-09-09     77.0
#
#                                                 title  vote_average  \
# 0                                      Batman Returns           6.6
# 1   The Beatles: Eight Days a Week - The Touring Y...           7.6
# 2                                          Blue Steel           5.4
# 3                                        Nightcrawler           7.6
# 4                                 She's Gotta Have It           6.2
# 5                                     The Dogs of War           4.9
# 6                                      In Old Chicago           5.0
# 7                                  Permanent Midnight           6.0
# 8                                    Bicentennial Man           6.9
# 9                                   Love and a Bullet           3.0
# 10                                             Arthur           6.5
# 11                                          Dragonfly           6.2
# 12                                              X-Men           6.8
# 13                                           Waitress           6.6
# 14                                         Encino Man           5.6
# 15                                           Kandahar           6.0
# 16                            The Ghost & Mr. Chicken           6.6
# 17       Harry Potter and the Deathly Hallows: Part 1           7.5
# 18                                     Love and Death           7.5
# 19                                       Corpse Bride           7.2
#
#                                              keywords  \
# 0   ['holiday', 'corruption', 'doublelife', 'dccom...
# 1                            ['music', 'documentary']
# 2   ['fight', 'wrongaccusal', 'lover', 'weapon', '...
# 3   ['journalism', 'underground', 'tvstation', 'so...
# 4                      ['independentfilm', 'lesbian']
# 5   ['africa', 'revolution', 'mercenary', 'battlef...
# 6                              ['chicago', 'musical']
# 7   ['alcohol', 'sex', 'adultery', 'heroin', 'poli...
# 8   ['android', 'hologram', 'freedom', 'futuristic...
# 9   ['villain', 'fistfight', 'sniperrifle', 'onema...
# 10                      ['newyorkcity', 'comicdrunk']
# 11  ['pregnancyandbirth', 'voice', 'dragonfly', 'c...
# 12  ['mutant', 'marvelcomic', 'superhero', 'basedo...
# 13  ['waitress', 'unwillinglypregnant', 'womandire...
# 14  ['stoneage', 'prehistoric', 'losangeles', 'cav...
# 15  ['islam', 'middleeast', 'refugee', 'afghanista...
# 16  ['newspaper', 'hauntedhouse', 'organ', 'slapst...
# 17  ['corruption', 'isolation', 'radio', 'magic', ...
# 18        ['napoleon', 'execution', 'anarchiccomedy']
# 19  ['shyness', 'england', 'cheating', 'oldtown', ...
#
#                                                  soup rating_id       est
# 0   holiday corruption doublelife dccomics crimefi...      1377  3.882785
# 1                 music documentary documentary music    163949  3.645886
# 2   fight wrongaccusal lover weapon psychopath pol...      5961  3.645886
# 3   journalism underground tvstation sociopath hom...    115569  3.645886
# 4              independentfilm lesbian comedy romance      3422  3.645886
# 5   africa revolution mercenary battlefield covert...      4842  3.645886
# 6                        chicago musical action drama     36553  3.645886
# 7   alcohol sex adultery heroin police party write...      2271  3.645886
# 8   android hologram freedom futuristic robot come...      3156  3.645886
# 9   villain fistfight sniperrifle onemanarmy villa...      5558  3.645886
# 10        newyorkcity comicdrunk comedy drama romance      3524  3.645886
# 11  pregnancyandbirth voice dragonfly carcrash jun...      5127  3.645886
# 12  mutant marvelcomic superhero basedoncomic supe...      3793  3.645886
# 13  waitress unwillinglypregnant womandirector comedy     50685  3.645886
# 14  stoneage prehistoric losangeles cavemen prehis...      3243  3.645886
# 15  islam middleeast refugee afghanistan famine mu...      4977  3.645886
# 16  newspaper hauntedhouse organ slapstick trial s...      6813  3.645886
# 17  corruption isolation radio magic teleportation...     81834  3.645886
# 18   napoleon execution anarchiccomedy history comedy      3814  3.645886
# 19  shyness england cheating oldtown grave skeleto...     37729  3.574632
